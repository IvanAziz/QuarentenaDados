# %%
print("Ivan Aziz")
# Out:
# Ivan Aziz

# %%
import pandas as pd

# %%
#Carregar a lista de notas para um DataFrame
avaliacoes = pd.read_csv("https://github.com/IvanAziz/QuarentenaDados/blob/master/ml-latest-small/ratings.csv?raw=true")
filmes = pd.read_csv("https://github.com/IvanAziz/QuarentenaDados/raw/master/ml-latest-small/movies.csv")

# %%
# Verifica as primeiras linhas de um DataFrame (Default Value = 5)
avaliacoes.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Verifica as dimenssões de um DataFrame
avaliacoes.shape

# %%
# Verifica o número de linhas de um DataFrame
len(avaliacoes)
# Out:
# 100836

# %%
#Redefinindo os nomes das colunas
avaliacoes.columns = ["usuarioId","filmeId","nota","momento"]
filmes.columns = ["filmeId", "titulo", "generos"]

# %%
#Filtrando avaliações apenas de um file específico
avaliacoes.query("filmeid == 1")

# %%
#Informações sobre o conjunto de dados
avaliacoes.describe()

# %%
avaliacoes["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
avaliacoes["nota"].describe()

# %%
avaliacoes.query("filmeid==1").describe()

# %%
avaliacoes.query("filmeid==1")["nota"].describe()

# %%
avaliacoes.query("filmeid==1")["nota"].mean()

# %%
avaliacoes.groupby("filmeId")["nota"].mean()

# %%
# não quero correr o risco de amanhã os filmes não estarem em quantidade exata e ter que alterar o meu código
# filmes["nota_media"] = notas_medias_por_filme
# filmes.head()

# %%
avaliacoes.query()
# Out:
# userId       3.261276e+02
# movieId      1.943530e+04
# rating       3.501557e+00
# timestamp    1.205946e+09
# dtype: float64

# %%
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas_medias_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()

# %%
notas_medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes_com_media = filmes.join(notas_medias_por_filme, on="filmeId")

# %%
filmes_com_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
# Out:
# 0       3.920930
# 1       3.431818
# 2       3.259615
# 3       2.357143
# 4       3.071429
#           ...
# 9737    4.000000
# 9738    3.500000
# 9739    3.500000
# 9740    3.500000
# 9741    4.000000
# Name: nota, Length: 9742, dtype: float64

# %%
filmes_com_media.sort_values("nota", ascending=False).head(15)
# Out:
#       filmeId  ... nota
# 7656    88448  ...  5.0
# 8107   100556  ...  5.0
# 9083   143031  ...  5.0
# 9094   143511  ...  5.0
# 9096   143559  ...  5.0
# 4251     6201  ...  5.0
# 8154   102217  ...  5.0
# 8148   102084  ...  5.0
# 4246     6192  ...  5.0
# 9122   145994  ...  5.0
# 8115   100906  ...  5.0
# 9129   146662  ...  5.0
# 8074    99636  ...  5.0
# 5785    31522  ...  5.0
# 9131   146684  ...  5.0
#
# [15 rows x 4 columns]

# %%
len(filmes_com_media)
# Out:
# 9742

# %%
filmes.query("filmeId==1")
filmes_com_media.query("filmeId==1")
# Out:
#    filmeId  ...     nota
# 0        1  ...  3.92093
#
# [1 rows x 4 columns]

# %%
len(filmes)
# Out:
# 9742

# %%
filmes_com_media.sort_values("nota").query("filmeId==1")
# Out:
#    filmeId  ...     nota
# 0        1  ...  3.92093
#
# [1 rows x 4 columns]

# %%
notas_medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes.head
# Out:
# <bound method NDFrame.head of       filmeId  ...                                      generos
# 0           1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1           2  ...                   Adventure|Children|Fantasy
# 2           3  ...                               Comedy|Romance
# 3           4  ...                         Comedy|Drama|Romance
# 4           5  ...                                       Comedy
# ...       ...  ...                                          ...
# 9737   193581  ...              Action|Animation|Comedy|Fantasy
# 9738   193583  ...                     Animation|Comedy|Fantasy
# 9739   193585  ...                                        Drama
# 9740   193587  ...                             Action|Animation
# 9741   193609  ...                                       Comedy
#
# [9742 rows x 3 columns]>

# %%
filmes_com_media.sort_values("nota", ascending=False).head(15)
# Out:
#       filmeId  ... nota
# 7656    88448  ...  5.0
# 8107   100556  ...  5.0
# 9083   143031  ...  5.0
# 9094   143511  ...  5.0
# 9096   143559  ...  5.0
# 4251     6201  ...  5.0
# 8154   102217  ...  5.0
# 8148   102084  ...  5.0
# 4246     6192  ...  5.0
# 9122   145994  ...  5.0
# 8115   100906  ...  5.0
# 9129   146662  ...  5.0
# 8074    99636  ...  5.0
# 5785    31522  ...  5.0
# 9131   146684  ...  5.0
#
# [15 rows x 4 columns]

# %%
avaliacoes.query("filmeId==1")["nota"].plot()

# %%
avaliacoes.query("filmeId==1")["nota"].plot(kind="hist", title="Avaliações do filme Toy Story")

# %%
#Desafio 1: Encontrar os filmes que não tiveram avaliação
filmes_com_media.query("nota == 'NaN'")
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %%
#Desafio 2: Mudar o nome da coluna “nota” para “média” após o Join.
filmes_com_media.rename(columns={'nota' : 'media'}, inplace=True)

# %%
filmes_com_media.head()
# Out:
#    filmeId  ...     media
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
#Desafio 3: Adicionar coluna e valor “quantidade avaliações”.

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
filmes_com_media.head()
# Out:
#    filmeId  ...     media
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
filmes = filmes.join(notas_medias_por_filme, on='filmeId')

# %%
filmes.head()
# Out:
#    filmeId                              titulo  ... quantidadeAvaliacoes      nota
# 0        1                    Toy Story (1995)  ...                215.0  3.920930
# 1        2                      Jumanji (1995)  ...                110.0  3.431818
# 2        3             Grumpier Old Men (1995)  ...                 52.0  3.259615
# 3        4            Waiting to Exhale (1995)  ...                  7.0  2.357143
# 4        5  Father of the Bride Part II (1995)  ...                 49.0  3.071429
#
# [5 rows x 5 columns]

# %%
total_avaliacoes_por_filme = avaliacoes.groupby('filmeId')['nota'].count()

# %%
total_avaliacoes_por_filme.head()
# Out:
# filmeId
# 1    215
# 2    110
# 3     52
# 4      7
# 5     49
# Name: nota, dtype: int64

# %%
total_avaliacoes_por_filme = avaliacoes.groupby('filmeId')['nota'].count()

# %%
filmes.head()
# Out:
#    filmeId                              titulo  ... quantidadeAvaliacoes      nota
# 0        1                    Toy Story (1995)  ...                215.0  3.920930
# 1        2                      Jumanji (1995)  ...                110.0  3.431818
# 2        3             Grumpier Old Men (1995)  ...                 52.0  3.259615
# 3        4            Waiting to Exhale (1995)  ...                  7.0  2.357143
# 4        5  Father of the Bride Part II (1995)  ...                 49.0  3.071429
#
# [5 rows x 5 columns]

# %%
filmes.rename(columns={'nota': 'quantidadeAvaliacoes'}, inplace=True)

# %%
filmes.head()
# Out:
#    filmeId  ... quantidadeAvaliacoes
# 0        1  ...             3.920930
# 1        2  ...             3.431818
# 2        3  ...             3.259615
# 3        4  ...             2.357143
# 4        5  ...             3.071429
#
# [5 rows x 5 columns]

# %%
#Desafio 4: Arredondar as médias para duas casas decimais.
filmes['quantidadeAvaliacoes'] = filmes['quantidadeAvaliacoes'].apply(lambda x: round(x, 2))
filmes.head()
# Out:
#    filmeId  ... quantidadeAvaliacoes
# 0        1  ...                 3.92
# 1        2  ...                 3.43
# 2        3  ...                 3.26
# 3        4  ...                 2.36
# 4        5  ...                 3.07
#
# [5 rows x 5 columns]

# %%
#Desafio 5: Descobrir os gêneros dos filmes (quais são eles, únicos)

# %%
generos = filmes['generos'].str.split(pat='|', expand=True)

# %%
generos
# Out:
#               0          1         2        3  ...     6     7     8     9
# 0     Adventure  Animation  Children   Comedy  ...  None  None  None  None
# 1     Adventure   Children   Fantasy     None  ...  None  None  None  None
# 2        Comedy    Romance      None     None  ...  None  None  None  None
# 3        Comedy      Drama   Romance     None  ...  None  None  None  None
# 4        Comedy       None      None     None  ...  None  None  None  None
# ...         ...        ...       ...      ...  ...   ...   ...   ...   ...
# 9737     Action  Animation    Comedy  Fantasy  ...  None  None  None  None
# 9738  Animation     Comedy   Fantasy     None  ...  None  None  None  None
# 9739      Drama       None      None     None  ...  None  None  None  None
# 9740     Action  Animation      None     None  ...  None  None  None  None
# 9741     Comedy       None      None     None  ...  None  None  None  None
#
# [9742 rows x 10 columns]

# %%
generos_filtrados = pd.melt(generos).dropna()

# %%
generos_filtrados
# Out:
#        variable      value
# 0             0  Adventure
# 1             0  Adventure
# 2             0     Comedy
# 3             0     Comedy
# 4             0     Comedy
# ...         ...        ...
# 66002         6       IMAX
# 73750         7   Thriller
# 75635         7    Mystery
# 85377         8   Thriller
# 95119         9    Western
#
# [22084 rows x 2 columns]

# %%
generos_filtrados.columns = ['indice','genero']

# %%
generos_filtrados
# Out:
#        indice     genero
# 0           0  Adventure
# 1           0  Adventure
# 2           0     Comedy
# 3           0     Comedy
# 4           0     Comedy
# ...       ...        ...
# 66002       6       IMAX
# 73750       7   Thriller
# 75635       7    Mystery
# 85377       8   Thriller
# 95119       9    Western
#
# [22084 rows x 2 columns]

# %%
generos = pd.DataFrame({'generos' : generos_filtrados['genero'].unique()})

# %%
generos
# Out:
#                generos
# 0            Adventure
# 1               Comedy
# 2               Action
# 3                Drama
# 4                Crime
# 5             Children
# 6              Mystery
# 7            Animation
# 8          Documentary
# 9             Thriller
# 10              Horror
# 11             Fantasy
# 12             Western
# 13           Film-Noir
# 14             Romance
# 15              Sci-Fi
# 16             Musical
# 17                 War
# 18  (no genres listed)
# 19                IMAX

# %% [markdown]
# Desafio 6: Contar quantos filmes por generos.

# %%
qtde_por_genero = generos_filtrados.groupby('genero').count()

# %%
qtde_por_genero
# Out:
#                     indice
# genero
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167

# %%
qtde_por_genero = qtde_por_genero.rename(columns={'indice': 'qtde'}).reset_index()

# %%
qtde_por_genero
# Out:
#                 genero  qtde
# 0   (no genres listed)    34
# 1               Action  1828
# 2            Adventure  1263
# 3            Animation   611
# 4             Children   664
# 5               Comedy  3756
# 6                Crime  1199
# 7          Documentary   440
# 8                Drama  4361
# 9              Fantasy   779
# 10           Film-Noir    87
# 11              Horror   978
# 12                IMAX   158
# 13             Musical   334
# 14             Mystery   573
# 15             Romance  1596
# 16              Sci-Fi   980
# 17            Thriller  1894
# 18                 War   382
# 19             Western   167

# %% [markdown]
# Desafio 7: Plotar o gráfico de aparições por gênero. Pode ser um gráfico de tipo igual a barra.

# %%
import matplotlib.pyplot as plt;

# %%
plt.figure(figsize=(30,10))

# %%
plt.title('Quantide de filmes por gênero')
# Out:
# Text(0.5, 1.0, 'Quantide de filmes por gênero')

# %%
plt.bar(qtde_por_genero['genero'], qtde_por_genero['qtde'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.figure(figsize=(20,10))

# %%
plt.bar(qtde_por_genero['genero'], qtde_por_genero['qtde'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.figure(figsize=(25,7))
plt.bar(qtde_por_genero['genero'], qtde_por_genero['qtde'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.figure(figsize=(25,12))
plt.bar(qtde_por_genero['genero'], qtde_por_genero['qtde'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.figure(figsize=(30,12))
plt.bar(qtde_por_genero['genero'], qtde_por_genero['qtde'])
# Out:
# <BarContainer object of 20 artists>
